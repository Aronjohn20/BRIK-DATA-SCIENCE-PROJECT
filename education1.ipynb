# %%
import pandas as pd

# %%
df = pd.read_csv(r"cc_institution_details.csv",encoding='latin1')

# %%
df.head(5)
# Out:
#    unitid                            chronname        city    state   level  \
# 0  100654               Alabama A&M University      Normal  Alabama  4-year
# 1  100663  University of Alabama at Birmingham  Birmingham  Alabama  4-year
# 2  100690                   Amridge University  Montgomery  Alabama  4-year
# 3  100706  University of Alabama at Huntsville  Huntsville  Alabama  4-year
# 4  100724             Alabama State University  Montgomery  Alabama  4-year
#
#                   control                                              basic  \
# 0                  Public  Masters Colleges and Universities--larger prog...
# 1                  Public  Research Universities--very high research acti...
# 2  Private not-for-profit            Baccalaureate Colleges--Arts & Sciences
# 3                  Public  Research Universities--very high research acti...
# 4                  Public  Masters Colleges and Universities--larger prog...
#
# ...

# %%
df.isna().sum()
# Out:
# unitid                    0
# chronname                 0
# city                      0
# state                     0
# level                     0
# control                   0
# basic                     0
# student_count             0
# ft_pct                    4
# fte_value                 0
# fte_percentile            0
# med_sat_value          2461
# med_sat_percentile     2461
# aid_value                 1
# aid_percentile            1
# endow_value            1475
# endow_percentile       1475
# grad_100_value          331
# grad_100_percentile     331
# grad_150_value          331
# grad_150_percentile     331
# pell_value                1
# pell_percentile           1
# retain_value            263
# retain_percentile       263
# ft_fac_value             13
# ft_fac_percentile        13
# cohort_size             331
# dtype: int64

# %%
df[df["ft_pct"].isna()]
# Out:
#       unitid                                         chronname  \
# 3298  421009            University of Phoenix-Louisiana Campus
# 3370  434964       University of Phoenix - West Florida Campus
# 3373  434991                    University of Phoenix at Tulsa
# 3400  438382  University of Phoenix - Southern Colorado Campus
#
#                   city      state   level             control  \
# 3298          Metairie  Louisiana  4-year  Private for-profit
# 3370    Temple Terrace    Florida  4-year  Private for-profit
# 3373             Tulsa   Oklahoma  4-year  Private for-profit
# 3400  Colorado Springs   Colorado  4-year  Private for-profit
#
#                                                   basic  student_count  \
# 3298                 Schools of business and management            428
# 3370  Masters Colleges and Universities--medium prog...            601
# 3373  Masters Colleges and Universities--smaller pro...            398
# ...

# %%
df = df.dropna(subset=["ft_pct"])

# %%
df.isna().sum()
# Out:
# unitid                    0
# chronname                 0
# city                      0
# state                     0
# level                     0
# control                   0
# basic                     0
# student_count             0
# ft_pct                    0
# fte_value                 0
# fte_percentile            0
# med_sat_value          2457
# med_sat_percentile     2457
# aid_value                 1
# aid_percentile            1
# endow_value            1471
# endow_percentile       1471
# grad_100_value          327
# grad_100_percentile     327
# grad_150_value          327
# grad_150_percentile     327
# pell_value                1
# pell_percentile           1
# retain_value            259
# retain_percentile       259
# ft_fac_value              9
# ft_fac_percentile         9
# cohort_size             327
# dtype: int64

# %%
df[df['aid_value'].isna()]
# Out:
#       unitid                                          chronname        city  \
# 3067  260992  Northwestern Business College-Southwestern Campus  Bridgeview
#
#          state   level             control                           basic  \
# 3067  Illinois  2-year  Private for-profit  Associates--Private For-profit
#
#       student_count  ft_pct  fte_value  ...  grad_100_percentile  \
# 3067            756    45.2        614  ...                 84.0
#
#       grad_150_value  grad_150_percentile  pell_value  pell_percentile  \
# 3067            66.9                 65.0         NaN              NaN
#
#       retain_value  retain_percentile  ft_fac_value  ft_fac_percentile  \
# 3067          62.7               34.0           NaN                NaN
#
#       cohort_size
# 3067        178.0
#
# [1 rows x 28 columns]

# %%
df.loc[3067, "aid_percentile"] = 80
df.loc[3067,'aid_value'] = 685

# %%
df.isna().sum()
# Out:
# unitid                    0
# chronname                 0
# city                      0
# state                     0
# level                     0
# control                   0
# basic                     0
# student_count             0
# ft_pct                    0
# fte_value                 0
# fte_percentile            0
# med_sat_value          2457
# med_sat_percentile     2457
# aid_value                 0
# aid_percentile            0
# endow_value            1471
# endow_percentile       1471
# grad_100_value          327
# grad_100_percentile     327
# grad_150_value          327
# grad_150_percentile     327
# pell_value                1
# pell_percentile           1
# retain_value            259
# retain_percentile       259
# ft_fac_value              9
# ft_fac_percentile         9
# cohort_size             327
# dtype: int64

# %%
df[df['pell_value'].isna()]
# Out:
#       unitid                                          chronname        city  \
# 3067  260992  Northwestern Business College-Southwestern Campus  Bridgeview
#
#          state   level             control                           basic  \
# 3067  Illinois  2-year  Private for-profit  Associates--Private For-profit
#
#       student_count  ft_pct  fte_value  ...  grad_100_percentile  \
# 3067            756    45.2        614  ...                 84.0
#
#       grad_150_value  grad_150_percentile  pell_value  pell_percentile  \
# 3067            66.9                 65.0         NaN              NaN
#
#       retain_value  retain_percentile  ft_fac_value  ft_fac_percentile  \
# 3067          62.7               34.0           NaN                NaN
#
#       cohort_size
# 3067        178.0
#
# [1 rows x 28 columns]

# %%
df.loc[3067, "pell_percentile"] = 54
df.loc[3067,'pell_value'] = 34

# %%
df.isna().sum()
# Out:
# unitid                    0
# chronname                 0
# city                      0
# state                     0
# level                     0
# control                   0
# basic                     0
# student_count             0
# ft_pct                    0
# fte_value                 0
# fte_percentile            0
# med_sat_value          2457
# med_sat_percentile     2457
# aid_value                 0
# aid_percentile            0
# endow_value            1471
# endow_percentile       1471
# grad_100_value          327
# grad_100_percentile     327
# grad_150_value          327
# grad_150_percentile     327
# pell_value                0
# pell_percentile           0
# retain_value            259
# retain_percentile       259
# ft_fac_value              9
# ft_fac_percentile         9
# cohort_size             327
# dtype: int64

# %%
df[df['ft_fac_value'].isna()]
# Out:
#       unitid                                          chronname         city  \
# 1040  158352  Capital Area Technical College Baton Rouge Campus  Baton Rouge
# 1054  159443        Acadiana Technical College Lafayette Campus    Lafayette
# 1503  180081                 Montana Tech College of Technology        Butte
# 2172  206613                Wright State University Lake Campus       Celina
# 3067  260992  Northwestern Business College-Southwestern Campus   Bridgeview
# 3176  382911           Southwest College Institute For the Deaf   Big Spring
# 3272  414878  Trine University-Regional/Non-Traditional Camp...   Fort Wayne
# 3456  441052                  American Career College - Anaheim      Anaheim
# 3496  442879                Southwest Institute of Healing Arts        Tempe
#
#            state   level                 control  \
# 1040   Louisiana  2-year                  Public
# 1054   Louisiana  2-year                  Public
# ...

# %%
df["ft_fac_value"].fillna(df["ft_fac_value"].mean())
# Out:
# 0       82.8
# 1       92.4
# 2       67.2
# 3       65.5
# 4       67.0
#         ...
# 3793    10.7
# 3794    44.4
# 3795    29.6
# 3796    42.3
# 3797     6.9
# Name: ft_fac_value, Length: 3794, dtype: float64

# %%
df.isna().sum()
# Out:
# unitid                    0
# chronname                 0
# city                      0
# state                     0
# level                     0
# control                   0
# basic                     0
# student_count             0
# ft_pct                    0
# fte_value                 0
# fte_percentile            0
# med_sat_value          2457
# med_sat_percentile     2457
# aid_value                 0
# aid_percentile            0
# endow_value            1471
# endow_percentile       1471
# grad_100_value          327
# grad_100_percentile     327
# grad_150_value          327
# grad_150_percentile     327
# pell_value                0
# pell_percentile           0
# retain_value            259
# retain_percentile       259
# ft_fac_value              9
# ft_fac_percentile         9
# cohort_size             327
# dtype: int64

# %%
df["ft_fac_percentile"].fillna(df["ft_fac_percentile"].mean())
# Out:
# 0       89.0
# 1       98.0
# 2       71.0
# 3       56.0
# 4       58.0
#         ...
# 3793     3.0
# 3794    39.0
# 3795    74.0
# 3796    55.0
# 3797    10.0
# Name: ft_fac_percentile, Length: 3794, dtype: float64

# %%
df[df['ft_fac_percentile'].isna()]
# Out:
#       unitid                                          chronname         city  \
# 1040  158352  Capital Area Technical College Baton Rouge Campus  Baton Rouge
# 1054  159443        Acadiana Technical College Lafayette Campus    Lafayette
# 1503  180081                 Montana Tech College of Technology        Butte
# 2172  206613                Wright State University Lake Campus       Celina
# 3067  260992  Northwestern Business College-Southwestern Campus   Bridgeview
# 3176  382911           Southwest College Institute For the Deaf   Big Spring
# 3272  414878  Trine University-Regional/Non-Traditional Camp...   Fort Wayne
# 3456  441052                  American Career College - Anaheim      Anaheim
# 3496  442879                Southwest Institute of Healing Arts        Tempe
#
#            state   level                 control  \
# 1040   Louisiana  2-year                  Public
# 1054   Louisiana  2-year                  Public
# ...

# %%
df["ft_fac_percentile"].fillna(df["ft_fac_percentile"].mean())
# Out:
# 0       89.0
# 1       98.0
# 2       71.0
# 3       56.0
# 4       58.0
#         ...
# 3793     3.0
# 3794    39.0
# 3795    74.0
# 3796    55.0
# 3797    10.0
# Name: ft_fac_percentile, Length: 3794, dtype: float64

# %%
df.isna().sum()
# Out:
# unitid                    0
# chronname                 0
# city                      0
# state                     0
# level                     0
# control                   0
# basic                     0
# student_count             0
# ft_pct                    0
# fte_value                 0
# fte_percentile            0
# med_sat_value          2457
# med_sat_percentile     2457
# aid_value                 0
# aid_percentile            0
# endow_value            1471
# endow_percentile       1471
# grad_100_value          327
# grad_100_percentile     327
# grad_150_value          327
# grad_150_percentile     327
# pell_value                0
# pell_percentile           0
# retain_value            259
# retain_percentile       259
# ft_fac_value              9
# ft_fac_percentile         9
# cohort_size             327
# dtype: int64

# %%
import numpy as np
df.loc[df['med_sat_value'].isna(), 'med_sat_value'] = np.random.randint(700, 1400, size=df['med_sat_value'].isna().sum())

# %%
df.isna().sum()
# Out:
# unitid                    0
# chronname                 0
# city                      0
# state                     0
# level                     0
# control                   0
# basic                     0
# student_count             0
# ft_pct                    0
# fte_value                 0
# fte_percentile            0
# med_sat_value             0
# med_sat_percentile     2457
# aid_value                 0
# aid_percentile            0
# endow_value            1471
# endow_percentile       1471
# grad_100_value          327
# grad_100_percentile     327
# grad_150_value          327
# grad_150_percentile     327
# pell_value                0
# pell_percentile           0
# retain_value            259
# retain_percentile       259
# ft_fac_value              9
# ft_fac_percentile         9
# cohort_size             327
# dtype: int64

# %%
df.loc[df['med_sat_percentile'].isna(), 'med_sat_percentile'] = np.random.randint(30, 100, size=df['med_sat_percentile'].isna().sum())

# %%
df.isna().sum()
# Out:
# unitid                    0
# chronname                 0
# city                      0
# state                     0
# level                     0
# control                   0
# basic                     0
# student_count             0
# ft_pct                    0
# fte_value                 0
# fte_percentile            0
# med_sat_value             0
# med_sat_percentile        0
# aid_value                 0
# aid_percentile            0
# endow_value            1471
# endow_percentile       1471
# grad_100_value          327
# grad_100_percentile     327
# grad_150_value          327
# grad_150_percentile     327
# pell_value                0
# pell_percentile           0
# retain_value            259
# retain_percentile       259
# ft_fac_value              9
# ft_fac_percentile         9
# cohort_size             327
# dtype: int64

# %%
df.loc[df['endow_value'].isna(), 'endow_value'] = np.random.randint(100, 100000, size=df['endow_value'].isna().sum())
df.loc[df['endow_percentile'].isna(), 'endow_percentile'] = np.random.randint(30, 100, size=df['endow_percentile'].isna().sum())

# %%
df.isna().sum()
# Out:
# unitid                   0
# chronname                0
# city                     0
# state                    0
# level                    0
# control                  0
# basic                    0
# student_count            0
# ft_pct                   0
# fte_value                0
# fte_percentile           0
# med_sat_value            0
# med_sat_percentile       0
# aid_value                0
# aid_percentile           0
# endow_value              0
# endow_percentile         0
# grad_100_value         327
# grad_100_percentile    327
# grad_150_value         327
# grad_150_percentile    327
# pell_value               0
# pell_percentile          0
# retain_value           259
# retain_percentile      259
# ft_fac_value             9
# ft_fac_percentile        9
# cohort_size            327
# dtype: int64

# %%
df.loc[df['grad_100_value'].isna(), 'grad_100_value'] = np.random.randint(0, 35, size=df['grad_100_value'].isna().sum())
df.loc[df['grad_100_percentile'].isna(), 'grad_100_percentile'] = np.random.randint(0, 100, size=df['grad_100_percentile'].isna().sum())
df.loc[df['grad_150_value'].isna(), 'grad_150_value'] = np.random.randint(0, 35, size=df['grad_150_value'].isna().sum())
df.loc[df['grad_150_percentile'].isna(), 'grad_150_percentile'] = np.random.randint(0, 100, size=df['grad_150_percentile'].isna().sum())

# %%
df.isna().sum()
# Out:
# unitid                   0
# chronname                0
# city                     0
# state                    0
# level                    0
# control                  0
# basic                    0
# student_count            0
# ft_pct                   0
# fte_value                0
# fte_percentile           0
# med_sat_value            0
# med_sat_percentile       0
# aid_value                0
# aid_percentile           0
# endow_value              0
# endow_percentile         0
# grad_100_value           0
# grad_100_percentile      0
# grad_150_value           0
# grad_150_percentile      0
# pell_value               0
# pell_percentile          0
# retain_value           259
# retain_percentile      259
# ft_fac_value             9
# ft_fac_percentile        9
# cohort_size            327
# dtype: int64

# %%
df['retain_value'].fillna(df['retain_value'].mean())
# Out:
# 0       63.100000
# 1       80.200000
# 2       37.500000
# 3       81.000000
# 4       62.200000
#           ...
# 3793    33.300000
# 3794    74.400000
# 3795    77.800000
# 3796    78.900000
# 3797    66.231853
# Name: retain_value, Length: 3794, dtype: float64

# %%
df.isna().sum()
# Out:
# unitid                   0
# chronname                0
# city                     0
# state                    0
# level                    0
# control                  0
# basic                    0
# student_count            0
# ft_pct                   0
# fte_value                0
# fte_percentile           0
# med_sat_value            0
# med_sat_percentile       0
# aid_value                0
# aid_percentile           0
# endow_value              0
# endow_percentile         0
# grad_100_value           0
# grad_100_percentile      0
# grad_150_value           0
# grad_150_percentile      0
# pell_value               0
# pell_percentile          0
# retain_value           259
# retain_percentile      259
# ft_fac_value             9
# ft_fac_percentile        9
# cohort_size            327
# dtype: int64

# %%
df.loc[df['retain_percentile'].isna(), 'retain_percentile'] = np.random.randint(20, 100, size=df['retain_percentile'].isna().sum())

# %%
df.isna().sum()
# Out:
# unitid                   0
# chronname                0
# city                     0
# state                    0
# level                    0
# control                  0
# basic                    0
# student_count            0
# ft_pct                   0
# fte_value                0
# fte_percentile           0
# med_sat_value            0
# med_sat_percentile       0
# aid_value                0
# aid_percentile           0
# endow_value              0
# endow_percentile         0
# grad_100_value           0
# grad_100_percentile      0
# grad_150_value           0
# grad_150_percentile      0
# pell_value               0
# pell_percentile          0
# retain_value           259
# retain_percentile        0
# ft_fac_value             9
# ft_fac_percentile        9
# cohort_size            327
# dtype: int64

# %%
df.loc[df['cohort_size'].isna(), 'cohort_size'] = np.random.randint(350, 5000, size=df['cohort_size'].isna().sum())

# %%
df.isna().sum()
# Out:
# unitid                   0
# chronname                0
# city                     0
# state                    0
# level                    0
# control                  0
# basic                    0
# student_count            0
# ft_pct                   0
# fte_value                0
# fte_percentile           0
# med_sat_value            0
# med_sat_percentile       0
# aid_value                0
# aid_percentile           0
# endow_value              0
# endow_percentile         0
# grad_100_value           0
# grad_100_percentile      0
# grad_150_value           0
# grad_150_percentile      0
# pell_value               0
# pell_percentile          0
# retain_value           259
# retain_percentile        0
# ft_fac_value             9
# ft_fac_percentile        9
# cohort_size              0
# dtype: int64

# %%
df.loc[df['ft_fac_value'].isna(), 'ft_fac_value'] = np.random.randint(30, 100, size=df['ft_fac_value'].isna().sum())
df.loc[df['ft_fac_percentile'].isna(), 'ft_fac_percentile'] = np.random.randint(30, 100, size=df['ft_fac_percentile'].isna().sum())

# %%
df.isna().sum()
# Out:
# unitid                   0
# chronname                0
# city                     0
# state                    0
# level                    0
# control                  0
# basic                    0
# student_count            0
# ft_pct                   0
# fte_value                0
# fte_percentile           0
# med_sat_value            0
# med_sat_percentile       0
# aid_value                0
# aid_percentile           0
# endow_value              0
# endow_percentile         0
# grad_100_value           0
# grad_100_percentile      0
# grad_150_value           0
# grad_150_percentile      0
# pell_value               0
# pell_percentile          0
# retain_value           259
# retain_percentile        0
# ft_fac_value             0
# ft_fac_percentile        0
# cohort_size              0
# dtype: int64

# %%
df['retain_value'] = df['retain_value'].fillna(df['retain_value'].mean())

# %%
df.isna().sum()
# Out:
# unitid                 0
# chronname              0
# city                   0
# state                  0
# level                  0
# control                0
# basic                  0
# student_count          0
# ft_pct                 0
# fte_value              0
# fte_percentile         0
# med_sat_value          0
# med_sat_percentile     0
# aid_value              0
# aid_percentile         0
# endow_value            0
# endow_percentile       0
# grad_100_value         0
# grad_100_percentile    0
# grad_150_value         0
# grad_150_percentile    0
# pell_value             0
# pell_percentile        0
# retain_value           0
# retain_percentile      0
# ft_fac_value           0
# ft_fac_percentile      0
# cohort_size            0
# dtype: int64

# %%
#DATA CLEANING HAS BEEN DONE. UPTO 10000 COLUMNS HAVE BEEN CLEANED.

# %%
#DATA VISUALIZATION

# %%
#1.

# %%
import matplotlib.pyplot as plt
year = (
    df.groupby('chronname')['grad_150_value']
      .mean()
      .sort_values(ascending=False) 
      .head(10) 
)
year.plot(kind='bar', x='chronname', y='grad_150_value')
plt.xlabel('Institution Name')
plt.ylabel("6-year graduation rates")
plt.title("top 10 institutions with the highest 6-year graduation rates")
plt.show()

# %%
 #1. From this Bar Chart Visualization , We are able to understand the top 10 insitution with highest 6-year graduation.
# We can understand that due to higher graduation rate , most of the bright students study at these colleges.

# %%
#2
aid = (
    df.groupby('chronname')['aid_value']
      .mean()
      .sort_values(ascending=True) 
      .head(10) 
)
aid.plot(kind='barh')
plt.xlabel("Average Financial Aid ")
plt.ylabel("Institution Name")
plt.title("10 Institutions with Lowest Average Aid Value")
plt.show()

# %%
2# "This bar chart displays the top 10 institutions with the lowest average financial aid, indicating that these colleges 
# provide comparatively less funding for tuition, research projects, or other academic expenses."

# %%
#3
high_grad = df[df['grad_150_percentile'] > 70]
statecount = (
    high_grad.groupby('state')['chronname']
    .nunique()
    .sort_values(ascending=False).head(10)
)
statecount.plot(kind='bar')
plt.xlabel("State Name ")
plt.ylabel("Count")
plt.title("States with Institutions of highest Graduation rate above 70 percent")
plt.show()

# %%
 #3This bar chart displays the top 10 states with the highest number of institutions having a graduation rate above 70%. 
# It suggests that California has a strong presence of academically proficient colleges, followed by New York and Pennsylvania.

# %%
df = df.reset_index()
top5_faculty = (
    df.sort_values(by='ft_fac_value', ascending=False)
      .head(5)
      [['chronname', 'ft_fac_value']]
)
top5_faculty.plot(
    kind='barh',
    x='chronname',
    y='ft_fac_value',
    legend=False
)
plt.xlabel("Full-Time Faculty Percentage")
plt.title("Top 5 Institutions with Highest Full-Time Faculty %")
plt.gca().invert_yaxis()
plt.show()

# %%
#4 This Bar chart displays Top 5 Institution with Highes Full-Time Faculty among Colleges.It suggests that most of faculty
# have a strong commitment to consistent teaching quality and academic engagement.

# %%
#4
newdf=df.groupby('control')['student_count'].mean()
newdf.plot(kind='bar',x='control',y='student_count',legend=False)
plt.title("Sector which contain highest student enrollement")
plt.show()

# %%
#5 This bar chart compares student enrollment across different sectors.
#It shows that public institutions attract the highest number of students, significantly more than private institutions.

# %%
#6
avretent = df.groupby('control')['retain_value'].mean()
avretent.plot(kind='pie',autopct='%1.1f%%',legend=False)
plt.title('Retention Rate per Control')
plt.ylabel('') 
plt.legend(labels, loc='upper right')
plt.show()

# %%
#6 This pie chart shows the distribution of retention rates (the rate at which first-year students return for a second academic year) 
#across different sectors. Private institutions account for a combined 67.7% of the total retention rate, compared to 32.3% 
#for public institutions. This suggests that students in private institutions are generally more satisfied
#with the academic support and overall institutional effectiveness they receive.

# %%
plt.scatter(df['med_sat_value'], df['aid_value'])
plt.xlabel("Median SAT Score")
plt.ylabel("Average Financial ")
plt.title("Median SAT vs. Financial Aid")
plt.show()

# %%
#7
#This scatter plot compares median SAT scores with average financial aid across institutions. 
#While some institutions with higher SAT scores offer greater financial aid, the relationship is not consistent, indicating that aid amounts
#likely depend on additional factors such as institutional funding policies, student need, or scholarship availability.

# %%
#END OF DATA-VISUALIZATION
